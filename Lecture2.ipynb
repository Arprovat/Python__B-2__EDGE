# %%
print ("Hello colab!")
print(123)
# Out:
# Hello colab!
# 123

# %%
'''
x = 12.2
y = 14
print(x)
print(y)
print("x: ", x, "y: ", y)
x = 100
print("x: ", x, "y: ", y)
name = "Jamal"
print("Hi", name, ". How are you?")
'''

name, age, city = "Jamal", 23, "Dhaka"
print(name)
print(age)
print(city)

a = b = "Hello"
print("Value of a:", a)
print("Value of b:", b)
# Out:
# Jamal
# 23
# Dhaka
# Value of a: Hello
# Value of b: Hello

# %%
print("Exercise 1:\n")

redius = float(input("Input redius of a circle: "))
PI = 3.14
area = PI * redius**2
print("Area of the circle is", area)

print("\nExercise 2:\n")
a = 10
b = 20
a = a + b
b = a - b
a = a - b
print(a)
print(b)

print("\nExercise 3:\n")

P = float(input("Enter Principal: "))
R = float(input("Enter Rate of interest: "))
T = float(input("Enter Time in years: "))
interest = (P * R * T)/100
print("Simple interest = ", interest)

print("\nExercise 4:\n")

celsius = 37
fahrenheit = (celsius * 9/5) +32
print ("Fahrenheit = ", fahrenheit)

print("\nExercise 5:\n")

length = float(input("Enter a length: "))
width = float(input("Enter a width: "))
print("Area of the rectangle is ", length * width)
print("Perimeter of the rectangle is ", 2 * (length + width))
# Out:
# Exercise 1:
#
# Input redius of a circle: 2
# Area of the circle is 12.56
#
# Exercise 2:
#
# 20
# 10
#
# Exercise 3:
#
# Enter Principal: 11
# Enter Rate of interest: 111
# Enter Time in years: 11
# Simple interest =  134.31
#
# Exercise 4:
#
# Fahrenheit =  98.6
#
# Exercise 5:
#
# Enter a length: 2
# Enter a width: 2
# Area of the rectangle is  4.0
# Perimeter of the rectangle is  8.0

# %%
x = 1 + 2 * 3 - 4 / 5 ** 6
print(x)
print(type(x))

# String conversion

sval = "123"
type(sval)
ival = int(sval)
print(ival + 1)
# Out:
# 6.999744
# <class 'float'>
# 124

# %%
print("Exercise 2.1:\n")

hours = float(input("Enter Hours: "))
rate = float(input("Enter Rate: "))
print("Pay: ", hours * rate)
# Out:
# Exercise 2.1:
#
# Enter Hours: 35
# Enter Rate: 2.75
# Pay:  96.25

# %%
print("Exercise 2.2:\n")

print(5 + 7)
print(5.2, "this", 4 - 2, "that", 5/2.0)
# Out:
# Exercise 2.2:
#
# 12
# 5.2 this 2 that 2.5

# %%
print("Exercise 2.3:\n")

str1 = "All"
str2 = "work"
str3 = "and"
str4 = "no"
str5 = "play"
str6 = "makes"
str7 = "Jack"
str8 = "a"
str9 = "dull"
str10 = "boy."
print(str1, str2, str3, str4, str5, str6, str7, str8, str9, str10)
# Out:
# Exercise 2.3:
#
# All work and no play makes Jack a dull boy.

# %%
print("Exercise 2.4:\n")
x = 6 * 1 - 2
print(x)
x = 6 * (1 - 2)
print(x)
# Out:
# Exercise 2.4:
#
# 4
# -6

# %%
print("Exercise 2.5:\n")


x = input()
type(x)
#x = raw_input()
# Out:
# Exercise 2.5:
#
# 4
# str

# %%
print("Exercise 2.6:\n")

#print(bruce + 4)
#name 'bruce' is not defined

bruce = 6
print(bruce + 4)
# Out:
# Exercise 2.6:
#
# 10

# %%
print("Exercise 2.7:\n")

noun1 = input("Enter a noun: ")
noun2 = input("Enter another noun: ")
plural_noun = input("Enter a plural noun: ")
verb_past = input("Enter a verb in past tense: ")
verb = input("Enter a verb: ")
adjective = input("Enter an adjective: ")
adverb = input("Enter an adverb: ")

story = f"""
Once upon a time, there was a {adjective} {noun1} who loved to {verb}
{adverb}. One day, it found a group of {plural_noun} playing with a {noun2}.
The {noun1} {verb_past} with joy and decided to join them.
Together, they all {verb}ed happily ever aftr!
"""
print(story)
# Out:
# Exercise 2.7:
#
# Enter a noun: boy
# Enter another noun: girl
# Enter a plural noun: boys
# Enter a verb in past tense: played
# Enter a verb: play
# Enter an adjective: honest
# Enter an adverb: well
#
# Once upon a time, there was a honest boy who loved to play
# well. One day, it found a group of boys playing with a girl.
# The boy played with joy and decided to join them.
# Together, they all played happily ever aftr!
