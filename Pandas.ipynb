# %% [markdown]
# <a href="https://colab.research.google.com/github/Arprovat/Python__B-2__EDGE/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas**
# It is python package which provide fast , flexible and one of the most powerfull data manupulation/analysis tool available in python and any language.
# It is built on the top of Numpy.
# ## **Data Type in Pandas**
# the two  primary type of pandas -
# - **Serise**: It is 1D data structure that can store same type of data,or we can say each coloum of *dataFrame* is a Serise.
# - **DataFrame**: It is 2D data structure that can store diffrent of type Like - int,flot,string in coloums,it is similar spreadsheet
#
# let's see how to create Datafream and appling methods...

# %%
import pandas as pd
import numpy as np

# %%
new_df = pd.DataFrame(np.random.randint(5, 20, size=(10,5)),columns=list('ABCDE')) #index=np.arange(10))

# %%
new_df
# Out:
#     A   B   C   D   E
# 0  18  12   5  18   5
# 1  10  17   6  11  19
# 2  12  16  12  19   9
# 3  13  11   5   7   6
# 4  12  18   6  12   8
# 5  17  19   7  18  12
# 6   5  10   9  16   8
# 7   9   7  11  17  19
# 8  16  13   8  19   8
# 9  18  11   8  19  16

# %%
dic_df = pd.DataFrame({
    "name":['provat','sahadat','nadim','masum'],
    'age':[22,23,23,23],
    "live":["BD",'saudi','Bd','Qatar']
} , index= np.arange(1,5))

# %%
dic_df
# Out:
#       name  age   live
# 1   provat   22     BD
# 2  sahadat   23  saudi
# 3    nadim   23     Bd
# 4    masum   23  Qatar

# %%
print(type(new_df))
print(type(dic_df['name']))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
dic_df.head(2)
# Out:
#       name  age   live
# 1   provat   22     BD
# 2  sahadat   23  saudi

# %%
dic_df.tail(3)
# Out:
#       name  age   live
# 2  sahadat   23  saudi
# 3    nadim   23     Bd
# 4    masum   23  Qatar

# %%
new_df.loc[0]['A']#return specified row
# Out:
# 18

# %%
dic_df.loc[1]['age']
# Out:
# 22

# %%
dic_df.loc[1:4:2] # slice using loc
# Out:
#      name  age live
# 1  provat   22   BD
# 3   nadim   23   Bd

# %%
dic_df.loc[:,['name','live']]
# Out:
#       name   live
# 1   provat     BD
# 2  sahadat  saudi
# 3    nadim     Bd
# 4    masum  Qatar

# %%
from google.colab import drive
drive.mount('/content/drive')
dic_df.to_excel('/content/drive/MyDrive/friends.xlsx')

# %%
pd.read_excel('/content/drive/MyDrive/friends.xlsx')

# %%
new_df.head(4)
# Out:
#     A   B   C   D   E
# 0  18  12   5  18   5
# 1  10  17   6  11  19
# 2  12  16  12  19   9
# 3  13  11   5   7   6

# %%
new_df.describe()
# Out:
#              A          B          C          D          E
# count  10.0000  10.000000  10.000000  10.000000  10.000000
# mean   13.0000  13.400000   7.700000  15.600000  11.000000
# std     4.2947   3.921451   2.406011   4.168666   5.228129
# min     5.0000   7.000000   5.000000   7.000000   5.000000
# 25%    10.5000  11.000000   6.000000  13.000000   8.000000
# 50%    12.5000  12.500000   7.500000  17.500000   8.500000
# 75%    16.7500  16.750000   8.750000  18.750000  15.000000
# max    18.0000  19.000000  12.000000  19.000000  19.000000

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       10 non-null     int64
#  1   B       10 non-null     int64
#  2   C       10 non-null     int64
#  3   D       10 non-null     int64
#  4   E       10 non-null     int64
# dtypes: int64(5)
# memory usage: 528.0 bytes

# %%
new_df.loc[:,['A']].sum()
# Out:
# A    130
# dtype: int64

# %%
new_df.loc[:,['A']].idxmax()
# Out:
# A    0
# dtype: int64

# %%
new_df.loc[:,['A']].to_numpy()
# Out:
# array([[18],
#        [10],
#        [12],
#        [13],
#        [12],
#        [17],
#        [ 5],
#        [ 9],
#        [16],
#        [18]])

# %%
new_df.loc[:,['A']].sort_values(by='A',ascending = False) #ascending true sort it ascending order
# Out:
#     A
# 0  18
# 9  18
# 5  17
# 8  16
# 3  13
# 2  12
# 4  12
# 1  10
# 7   9
# 6   5

# %%
NaN=np.NaN
new_df.loc[0,"A"]= NaN

# %%
new_df.head(3)
# Out:
#       A   B   C   D   E
# 0   NaN  12   5  18   5
# 1  10.0  17   6  11  19
# 2  12.0  16  12  19   9

# %%
new_df.dropna(subset= ["A"])#determine NaN value in only A coloum
# Out:
#       A   B   C   D   E
# 1  10.0  17   6  11  19
# 2  12.0  16  12  19   9
# 3  13.0  11   5   7   6
# 4  12.0  18   6  12   8
# 5  17.0  19   7  18  12
# 6   5.0  10   9  16   8
# 7   9.0   7  11  17  19
# 8  16.0  13   8  19   8
# 9  18.0  11   8  19  16

# %%
new_df.fillna(value=0)#fill NaN with O
# Out:
#       A   B   C   D   E
# 0   0.0  12   5  18   5
# 1  10.0  17   6  11  19
# 2  12.0  16  12  19   9
# 3  13.0  11   5   7   6
# 4  12.0  18   6  12   8
# 5  17.0  19   7  18  12
# 6   5.0  10   9  16   8
# 7   9.0   7  11  17  19
# 8  16.0  13   8  19   8
# 9  18.0  11   8  19  16

# %%
new_df.dropna(axis=1  )#drop coloum with NaN (inplace=true) change in main dataframe no need to store in variable
# Out:
#     B   C   D   E
# 0  12   5  18   5
# 1  17   6  11  19
# 2  16  12  19   9
# 3  11   5   7   6
# 4  18   6  12   8
# 5  19   7  18  12
# 6  10   9  16   8
# 7   7  11  17  19
# 8  13   8  19   8
# 9  11   8  19  16

# %%
new_df.drop("C",axis=1)#drop coloum
# Out:
#       A   B   D   E
# 0   NaN  12  18   5
# 1  10.0  17  11  19
# 2  12.0  16  19   9
# 3  13.0  11   7   6
# 4  12.0  18  12   8
# 5  17.0  19  18  12
# 6   5.0  10  16   8
# 7   9.0   7  17  19
# 8  16.0  13  19   8
# 9  18.0  11  19  16

# %%
new_df.drop(0,axis=0)#drop row
# Out:
#       A   B   C   D   E
# 1  10.0  17   6  11  19
# 2  12.0  16  12  19   9
# 3  13.0  11   5   7   6
# 4  12.0  18   6  12   8
# 5  17.0  19   7  18  12
# 6   5.0  10   9  16   8
# 7   9.0   7  11  17  19
# 8  16.0  13   8  19   8
# 9  18.0  11   8  19  16

# %%
new_df.loc[(new_df['A']>15) & (new_df['B']<18)]
# Out:
#       A   B  C   D   E
# 8  16.0  13  8  19   8
# 9  18.0  11  8  19  16

# %%
 new_df[~((new_df['A'] > 15) & (new_df['B'] < 18))]
# Out:
#       A   B   C   D   E
# 0   NaN  12   5  18   5
# 1  10.0  17   6  11  19
# 2  12.0  16  12  19   9
# 3  13.0  11   5   7   6
# 4  12.0  18   6  12   8
# 5  17.0  19   7  18  12
# 6   5.0  10   9  16   8
# 7   9.0   7  11  17  19

# %%
new_df.duplicated(subset=['A'],keep = "first")
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
new_df.duplicated(subset=['A','C'],keep = False)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool
